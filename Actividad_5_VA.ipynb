# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## ATHENAS

# %%
data = pd.read_csv('ATHENAS_DATALIMPIO.csv')
data
# Out:
#        Unnamed: 0.1  Unnamed: 0                   id    host_id  \
# 0                 0           0                27262      37177
# 1                 1           1               809874    4259738
# 2                 2           2               866381    4551671
# 3                 3           3               886724    4700824
# 4                 4           4               896212    4777984
# ...             ...         ...                  ...        ...
# 14637         14637       14637  1318251942056598277   25811452
# 14638         14638       14638  1318276742106864141  666320836
# 14639         14639       14639  1318307768558324736  221534605
# 14640         14640       14640  1318405788507138933  650411545
# 14641         14641       14641  1318601800941001079   31290848
#
#        host_listings_count  host_total_listings_count   latitude  longitude  \
# 0                        4                         12  37.989240  23.765000
# ...

# %%
data.isnull().sum()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14642 entries, 0 to 14641
# Data columns (total 52 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0.1                                  14642 non-null  int64
#  1   Unnamed: 0                                    14642 non-null  int64
#  2   id                                            14642 non-null  int64
#  3   host_id                                       14642 non-null  int64
#  4   host_listings_count                           14642 non-null  int64
#  5   host_total_listings_count                     14642 non-null  int64
#  6   latitude                                      14642 non-null  float64
#  7   longitude                                     14642 non-null  float64
#  8   accommodates                                  14642 non-null  int64
# ...

# %%
#Eliminar columnas innecesarias
#axis = 1 para columnas
#axis = 0 para filas
data1= data.drop(['Unnamed: 0' ], axis=1)
data2= data1.drop(['Unnamed: 0.1' ], axis=1)
data2
# Out:
#                         id    host_id  host_listings_count  \
# 0                    27262      37177                    4
# 1                   809874    4259738                    2
# 2                   866381    4551671                    1
# 3                   886724    4700824                    1
# 4                   896212    4777984                   29
# ...                    ...        ...                  ...
# 14637  1318251942056598277   25811452                    3
# 14638  1318276742106864141  666320836                    2
# 14639  1318307768558324736  221534605                   53
# 14640  1318405788507138933  650411545                    1
# 14641  1318601800941001079   31290848                  109
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# 0                             12  37.989240  23.765000             2
# 1                              2  37.962150  23.721790             4
# ...

# %%
valores_null = data2.isnull().sum()
valores_null
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14642 entries, 0 to 14641
# Data columns (total 50 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            14642 non-null  int64
#  1   host_id                                       14642 non-null  int64
#  2   host_listings_count                           14642 non-null  int64
#  3   host_total_listings_count                     14642 non-null  int64
#  4   latitude                                      14642 non-null  float64
#  5   longitude                                     14642 non-null  float64
#  6   accommodates                                  14642 non-null  int64
#  7   bathrooms                                     14642 non-null  float64
#  8   bedrooms                                      14642 non-null  float64
# ...

# %%
#Creo 2 dataframe para poder porcesar los outliers
#se deben seleccionar y separar lo valores cualitativos de cuantitativos

cuantitativas = data2.iloc[ : , :37]   #todas las filas, pero columnas de 1 a la 36
cualitativas = data2.iloc[ : , 37:]  #columna 37 a la última

# %% [markdown]
# ## Diagrama de caja por columna

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['id'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['host_id'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['host_listings_count'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['host_total_listings_count'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['latitude'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['longitude'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['accommodates'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['bathrooms'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['bedrooms'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['beds'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['minimum_nights'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['maximum_nights'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['minimum_minimum_nights'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['maximum_minimum_nights'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['minimum_maximum_nights'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['maximum_maximum_nights'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['minimum_nights_avg_ntm'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['maximum_nights_avg_ntm'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['availability_30'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['availability_60'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['availability_90'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['availability_365'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['number_of_reviews'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['number_of_reviews_ltm'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['number_of_reviews_l30d'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['review_scores_rating'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['review_scores_accuracy'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['review_scores_cleanliness'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['review_scores_checkin'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['review_scores_communication'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['review_scores_location'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['review_scores_value'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['calculated_host_listings_count'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['calculated_host_listings_count_entire_homes'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['calculated_host_listings_count_private_rooms'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['calculated_host_listings_count_shared_rooms'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativas['reviews_per_month'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %% [markdown]
# ## Limpiar cuantitativas

# %%
#Todo esto iria en el fata frame 

y = cuantitativas 
percentiles25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentiles25

Limite_superior_iqr = percentile75 + 1.5*iqr
Limite_inferior_iqr = percentile75 - 1.5*iqr

print("Limite superior permitido",Limite_superior_iqr)
print("Limite inferior permitido",Limite_inferior_iqr)
# Out:
# Limite superior permitido id                                              2.795075e+18
# host_id                                         1.051935e+09
# host_listings_count                             5.950000e+01
# host_total_listings_count                       6.950000e+01
# latitude                                        3.801562e+01
# longitude                                       2.375695e+01
# accommodates                                    7.000000e+00
# bathrooms                                       1.000000e+00
# bedrooms                                        3.500000e+00
# beds                                            3.500000e+00
# minimum_nights                                  3.500000e+00
# maximum_nights                                  1.735000e+03
# minimum_minimum_nights                          3.500000e+00
# maximum_minimum_nights                          6.000000e+00
# minimum_maximum_nights                          2.265000e+03
# ...

# %%
data3_iqr = cuantitativas[(y<=Limite_superior_iqr)&(y>=Limite_inferior_iqr)]
data3_iqr

#todos los que queden fuera se volveran nulos
# Out:
#                         id    host_id  host_listings_count  \
# 0                    27262      37177                  4.0
# 1                   809874    4259738                  2.0
# 2                   866381    4551671                  1.0
# 3                   886724    4700824                  1.0
# 4                   896212    4777984                 29.0
# ...                    ...        ...                  ...
# 14637  1318251942056598277   25811452                  3.0
# 14638  1318276742106864141  666320836                  2.0
# 14639  1318307768558324736  221534605                 53.0
# 14640  1318405788507138933  650411545                  1.0
# 14641  1318601800941001079   31290848                  NaN
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# 0                           12.0  37.989240        NaN           2.0
# 1                            2.0  37.962150  23.721790           4.0
# ...

# %%
valores_null = data3_iqr.isnull().sum()
valores_null
# Out:
# id                                                 0
# host_id                                            0
# host_listings_count                             1544
# host_total_listings_count                       1669
# latitude                                         577
# longitude                                       2070
# accommodates                                     556
# bathrooms                                       3696
# bedrooms                                        1098
# beds                                            2588
# minimum_nights                                   960
# maximum_nights                                     1
# minimum_minimum_nights                           903
# maximum_minimum_nights                           620
# minimum_maximum_nights                             1
# maximum_maximum_nights                             1
# minimum_nights_avg_ntm                          1279
# maximum_nights_avg_ntm                             1
# ...

# %%
data3_iqr = data3_iqr.fillna(round(data3_iqr.mean(),1))
data3_iqr
# Out:
#                         id    host_id  host_listings_count  \
# 0                    27262      37177                  4.0
# 1                   809874    4259738                  2.0
# 2                   866381    4551671                  1.0
# 3                   886724    4700824                  1.0
# 4                   896212    4777984                 29.0
# ...                    ...        ...                  ...
# 14637  1318251942056598277   25811452                  3.0
# 14638  1318276742106864141  666320836                  2.0
# 14639  1318307768558324736  221534605                 53.0
# 14640  1318405788507138933  650411545                  1.0
# 14641  1318601800941001079   31290848                 11.0
#
#        host_total_listings_count   latitude  longitude  accommodates  \
# 0                           12.0  37.989240  23.700000           2.0
# 1                            2.0  37.962150  23.721790           4.0
# ...

# %%
dato_limpios = pd.concat([ data3_iqr, cualitativas], axis=1)
dato_limpios.info()
dato_limpios.to_csv("Athenas_sin_VA.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14642 entries, 0 to 14641
# Data columns (total 50 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            14642 non-null  int64
#  1   host_id                                       14642 non-null  int64
#  2   host_listings_count                           14642 non-null  float64
#  3   host_total_listings_count                     14642 non-null  float64
#  4   latitude                                      14642 non-null  float64
#  5   longitude                                     14642 non-null  float64
#  6   accommodates                                  14642 non-null  float64
#  7   bathrooms                                     14642 non-null  float64
#  8   bedrooms                                      14642 non-null  float64
# ...

# %%
valores_null = dato_limpios.isnull().sum()
valores_null
# Out:
# id                                              0
# host_id                                         0
# host_listings_count                             0
# host_total_listings_count                       0
# latitude                                        0
# longitude                                       0
# accommodates                                    0
# bathrooms                                       0
# bedrooms                                        0
# beds                                            0
# minimum_nights                                  0
# maximum_nights                                  0
# minimum_minimum_nights                          0
# maximum_minimum_nights                          0
# minimum_maximum_nights                          0
# maximum_maximum_nights                          0
# minimum_nights_avg_ntm                          0
# maximum_nights_avg_ntm                          0
# availability_30                                 0
# ...

# %% [markdown]
# ## MÉXICO

# %%
mexico = pd.read_csv('listings.csv')
mexico
# Out:
#                         id                                               name  \
# 0                   499553      Deluxe 4-BR penthouse, views, historic center
# 1                   501037                The best cheap flat in La Condesa!!
# 2                   517503                         Nice big room near airport
# 3                   527473  Nuestro bello departamento, un paraíso en la C...
# 4                   544105  Polanco great location! Priv Room in Shared Apart
# ...                    ...                                                ...
# 26276  1318906185008171760                             Suite Dumas Polanco 8D
# 26277  1318960023050066631                     Departamento amueblado en CDMX
# 26278  1318997244771691320                         hospedaje en Coyoacán CDMX
# 26279  1319078571963617776            3 recámaras 3 baños con estacionamiento
# 26280  1319509843525848258  Loft ejecutivo junto a Reforma y a pasos del Á...
#
# ...

# %%
mexico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26281 entries, 0 to 26280
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              26281 non-null  int64
#  1   name                            26281 non-null  object
#  2   host_id                         26281 non-null  int64
#  3   host_name                       26278 non-null  object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   26281 non-null  object
#  6   latitude                        26281 non-null  float64
#  7   longitude                       26281 non-null  float64
#  8   room_type                       26281 non-null  object
#  9   price                           22466 non-null  float64
#  10  minimum_nights                  26281 non-null  int64
#  11  number_of_reviews               26281 non-null  int64
# ...

# %%
dataM  = mexico.fillna(method= 'ffill')
dataM
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_10196\2667782190.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataM  = mexico.fillna(method= 'ffill')
#                         id                                               name  \
# 0                   499553      Deluxe 4-BR penthouse, views, historic center
# 1                   501037                The best cheap flat in La Condesa!!
# 2                   517503                         Nice big room near airport
# 3                   527473  Nuestro bello departamento, un paraíso en la C...
# 4                   544105  Polanco great location! Priv Room in Shared Apart
# ...                    ...                                                ...
# 26276  1318906185008171760                             Suite Dumas Polanco 8D
# 26277  1318960023050066631                     Departamento amueblado en CDMX
# ...

# %%
valores_null = dataM.isnull().sum()
valores_null
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group               26281
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                           0
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# license                           26281
# dtype: int64

# %%
#Eliminar columnas innecesarias
#axis = 1 para columnas
#axis = 0 para filas
dataM= dataM.drop(['neighbourhood_group' ], axis=1)
dataM= dataM.drop(['license' ], axis=1)
dataM
# Out:
#                         id                                               name  \
# 0                   499553      Deluxe 4-BR penthouse, views, historic center
# 1                   501037                The best cheap flat in La Condesa!!
# 2                   517503                         Nice big room near airport
# 3                   527473  Nuestro bello departamento, un paraíso en la C...
# 4                   544105  Polanco great location! Priv Room in Shared Apart
# ...                    ...                                                ...
# 26276  1318906185008171760                             Suite Dumas Polanco 8D
# 26277  1318960023050066631                     Departamento amueblado en CDMX
# 26278  1318997244771691320                         hospedaje en Coyoacán CDMX
# 26279  1319078571963617776            3 recámaras 3 baños con estacionamiento
# 26280  1319509843525848258  Loft ejecutivo junto a Reforma y a pasos del Á...
#
# ...

# %%
dataM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26281 entries, 0 to 26280
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              26281 non-null  int64
#  1   name                            26281 non-null  object
#  2   host_id                         26281 non-null  int64
#  3   host_name                       26281 non-null  object
#  4   neighbourhood                   26281 non-null  object
#  5   latitude                        26281 non-null  float64
#  6   longitude                       26281 non-null  float64
#  7   room_type                       26281 non-null  object
#  8   price                           26281 non-null  float64
#  9   minimum_nights                  26281 non-null  int64
#  10  number_of_reviews               26281 non-null  int64
#  11  last_review                     26281 non-null  object
# ...

# %%
#Selecionar variables 

cuantitativasM = dataM.iloc[ : , [0,2,5,6,8,9,10,12,13,14,15]]   
cualitativasM = dataM.iloc[ : , [1,3,4,7,11]]

# %% [markdown]
# ## Diagrama de caja por columna

# %%
fig = plt.figure(figsize = (15,8))
cuantitativasM['id'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativasM['host_id'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativasM['latitude'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativasM['longitude'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativasM['price'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativasM['minimum_nights'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativasM['number_of_reviews'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativasM['reviews_per_month'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativasM['calculated_host_listings_count'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativasM['availability_365'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %%
fig = plt.figure(figsize = (15,8))
cuantitativasM['number_of_reviews_ltm'].plot(kind='box', vert =False)
plt.title("Valores Atípicos del Dataframe")
plt.show()

# %% [markdown]
# # Aplicación del método para limpiar outliers

# %%
#Todo esto iria en el fata frame 

y = cuantitativasM 
percentiles25 = y.quantile(0.25) #Q1
percentile75 = y.quantile(0.75) #Q3
iqr = percentile75 - percentiles25

Limite_superior_iqr = percentile75 + 1.5*iqr
Limite_inferior_iqr = percentile75 - 1.5*iqr

print("Limite superior permitido",Limite_superior_iqr)
print("Limite inferior permitido",Limite_inferior_iqr)
# Out:
# Limite superior permitido id                                2.600145e+18
# host_id                           8.860262e+08
# latitude                          1.949298e+01
# longitude                        -9.911830e+01
# price                             3.691500e+03
# minimum_nights                    3.500000e+00
# number_of_reviews                 1.480000e+02
# reviews_per_month                 5.645000e+00
# calculated_host_listings_count    2.600000e+01
# availability_365                  7.390000e+02
# number_of_reviews_ltm             5.500000e+01
# dtype: float64
# Limite inferior permitido id                               -5.200291e+17
# host_id                          -1.154617e+08
# latitude                          1.937082e+01
# longitude                        -9.919112e+01
# price                             5.850000e+01
# minimum_nights                    5.000000e-01
# number_of_reviews                -2.600000e+01
# reviews_per_month                -5.650000e-01
# ...

# %%
dataM_iqr = cuantitativasM[(y<=Limite_superior_iqr) & (y>=Limite_inferior_iqr)]
dataM_iqr

#todos los que queden fuera se volveran nulos
# Out:
#                         id    host_id   latitude  longitude   price  \
# 0                   499553    1297488  19.436210 -99.138740     NaN
# 1                   501037    1364145  19.415780 -99.174250  1150.0
# 2                   517503    2547499  19.437840        NaN   550.0
# 3                   527473     158585  19.418870 -99.173330  3654.0
# 4                   544105    2674950  19.442892        NaN  1007.0
# ...                    ...        ...        ...        ...     ...
# 26276  1318906185008171760  369403303  19.436998        NaN   760.0
# 26277  1318960023050066631  525554527  19.449230 -99.136170     NaN
# 26278  1318997244771691320  293574406        NaN        NaN   227.0
# 26279  1319078571963617776   35255741  19.400096 -99.172981  3125.0
# 26280  1319509843525848258  333035396  19.427799 -99.163842   918.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 0                 3.0               26.0               0.17
# ...

# %%
valores_null = dataM_iqr.isnull().sum()
valores_null
# Out:
# id                                   0
# host_id                              0
# latitude                          4891
# longitude                         5307
# price                             2188
# minimum_nights                    3523
# number_of_reviews                 2177
# reviews_per_month                  986
# calculated_host_listings_count    3380
# availability_365                     0
# number_of_reviews_ltm             1207
# dtype: int64

# %%
dataM_iqr = dataM_iqr.fillna(round(dataM_iqr.mean(),1))
dataM_iqr
# Out:
#                         id    host_id   latitude  longitude   price  \
# 0                   499553    1297488  19.436210 -99.138740  1216.8
# 1                   501037    1364145  19.415780 -99.174250  1150.0
# 2                   517503    2547499  19.437840 -99.200000   550.0
# 3                   527473     158585  19.418870 -99.173330  3654.0
# 4                   544105    2674950  19.442892 -99.200000  1007.0
# ...                    ...        ...        ...        ...     ...
# 26276  1318906185008171760  369403303  19.436998 -99.200000   760.0
# 26277  1318960023050066631  525554527  19.449230 -99.136170  1216.8
# 26278  1318997244771691320  293574406  19.400000 -99.200000   227.0
# 26279  1319078571963617776   35255741  19.400096 -99.172981  3125.0
# 26280  1319509843525848258  333035396  19.427799 -99.163842   918.0
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# 0                 3.0               26.0               0.17
# ...

# %%
dato_limpiosM = pd.concat([cualitativasM,dataM_iqr], axis=1)
dato_limpiosM
# Out:
#                                                     name         host_name  \
# 0          Deluxe 4-BR penthouse, views, historic center             Petra
# 1                    The best cheap flat in La Condesa!!          Humberto
# 2                             Nice big room near airport      Irma Adriana
# 3      Nuestro bello departamento, un paraíso en la C...          Fernando
# 4      Polanco great location! Priv Room in Shared Apart         Elizabeth
# ...                                                  ...               ...
# 26276                             Suite Dumas Polanco 8D          Grissell
# 26277                     Departamento amueblado en CDMX           Partner
# 26278                         hospedaje en Coyoacán CDMX  Bellanira Isabel
# 26279            3 recámaras 3 baños con estacionamiento              Juan
# 26280  Loft ejecutivo junto a Reforma y a pasos del Á...              Clau
#
# ...

# %%
dato_limpiosM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26281 entries, 0 to 26280
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            26281 non-null  object
#  1   host_name                       26281 non-null  object
#  2   neighbourhood                   26281 non-null  object
#  3   room_type                       26281 non-null  object
#  4   last_review                     26281 non-null  object
#  5   id                              26281 non-null  int64
#  6   host_id                         26281 non-null  int64
#  7   latitude                        26281 non-null  float64
#  8   longitude                       26281 non-null  float64
#  9   price                           26281 non-null  float64
#  10  minimum_nights                  26281 non-null  float64
#  11  number_of_reviews               26281 non-null  float64
# ...

# %%
dato_limpiosM.to_csv("DATOS_LIMPIOS_MEXICO.csv")
